# %% [markdown]
# # Explore here

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

# load the .env file variables
load_dotenv()

client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')

print(client_id)
print(client_secret)
# spotify = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id = client_id, client_secret = client_secret))
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

artist_id = "3P3iJ6AlAdlb4tYAu00Fhk"

# TODO: Use .artist_top_tracks(artist_id) to get the artist's top tracks
response = spotify.artist_top_tracks(artist_id)

# TODO: Sort through the response to get the top `tracks`

response
# Let's print `tracks` to verify
# `tracks` is a list of dictionaries where each dictionary represents a Bad Bunny song


all_tracks = response['tracks']

print(all_tracks)

rows = []

for data in all_tracks:
    # print(data.keys())
    print(data['name'], data['popularity'], data['duration_ms'])

    dictionary = {'name': data['name'], 'popularity': data['popularity'], 'duration': data['duration_ms']}

    rows.append(dictionary)

print(rows)
# Out:
# 656739b507744d84b9f2257ec2e5a507
# 1a43c8d7316a49c79598384de5318376
# ...

# %%
import pandas as pd

df = pd.DataFrame(rows)

df
# Out:
#                 name  popularity  duration
# 0     Lunar Guidance          53    165173
# 1         Shenandoah          51    130500
# 2          Beachtown          47    234285
# 3       The Way Home          46    239080
# 4                6-7          44    215448
# 5  Curse the Weather          43    298040
# 6         Card Shark          43    212968
# 7             Pearls          42    208401
# 8           New Tide          42    291709
# 9            Restive          39    208252

# %%
'''
Step 7
A scatter plot is a good alternative to determine visually and graphically whether two variables may or may not be related to each other:
'''
import seaborn as sns
import matplotlib.pyplot as plt


plt.scatter(df['popularity'], df['duration'])

plt.title('Popularity vs Duration Chart')
plt.xlabel('Popularity')
plt.ylabel('Duration')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='popularity', y='duration', data=df)


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
